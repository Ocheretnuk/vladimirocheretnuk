# %% [markdown]
# ### ТИПЫ ДАННЫХ
# Числа                    1234, 3.1415, 3+4j, Decimal, Fraction
# Строки                   spam’, “guido’s” , b’a\x01c’
# Списки                   [1, [2, ‘three’], 4]
# Кортежи                  (1,’spam’, 4, ‘U’)
# Словари                  {‘food’: ‘spam’, ‘taste’: ‘yum’}
# Множества                set(‘abc’), {‘a’, ‘b’, ‘c’}
# Файлы                    myfile = open(‘eggs’, ‘r’)
# Прочие базовые типы      None, логические значения

# %% [markdown]
# ## ОТКРЫТИЕ ФАЙЛА

# %%
with open('transactions_data.csv', 'r') as f:
          for line in f:
              print (line)

# %%
with open(r'C:\Users\Стас\Documents\Python ANAL\transactions_data.csv', 'r') as f:
          for line in f:
              print (line + "nahs")

# %% [markdown]
# тут срезаем пропуски,  из-за того, что в текстовых файлах в конце строки всегда стоит служебный символ переноса строк

# %%
with open('transactions_data.csv', 'r') as f:
          for line in f:
              print (line.strip())

# %% [markdown]
# запишем данные в лист,

# %%
ids = []
with open('power.txt', 'r') as f:
    for line in f:
        id = line.strip()        
        ids.append(id)
        print (ids)

# %% [markdown]
# format

# %%
print( 'Уникальных ID в файле {}'.format("sds"))

# %% [markdown]
# ### Работа с excel файлами

# %%
import openpyxl

workbook = 'data.xlsx'
sheetName = 'data'

sheet = openpyxl.load_workbook(workbook)[sheetName]

#for line in sheet['A2:I4']:
#   print(line)

# Ну а тут выводим значения определяем границы , и указываем что выводить

for line in sheet[ 'E2:I5' ]:
    medium = line[0].value
    source = line[1].value
    amount_paid = line[4].value
    #print( source, medium, amount_paid )
    
# посчитаем сумму значений, сумирование в цикле

total_amount_paid = 0
for line in sheet[ 'E2:I295' ]:  
    amount_paid = line[4].value
    
    total_amount_paid += amount_paid
print (total_amount_paid)
# Out:
# 5129.8

# %% [markdown]
# ### Словари

# %%
total_costs = {'google': 1319, 'yandex': 1818, 'promo': 1181}

#прибавили 1 к значению и сложили стобцы
total_costs['google'] += 1
total_costs['google'] += 1
k = total_costs['google'] + total_costs['promo']
#print (k)
#print (total_costs)

#проверка ключей
source = 'brand'

if source in total_costs:
    print('Расходы на источник {} составили {} рублей'.format(source, total_costs['google']))
else:
    print('Источник {} не найден в итоговой статистике'.format(source))

# Добавление новых значений в цикле

users_stats_dict = {}

i = 0

with open('data_no_header.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        current_user_id = line[2]

                # если ID пользователя уже есть в нашем словаре, то добавляем ему +1

        if current_user_id in users_stats_dict:
            users_stats_dict[ current_user_id ] += 1

        else:
            users_stats_dict[ current_user_id ] = 1

        print( 'Текущий ID: {}'.format( current_user_id ) )
        print( users_stats_dict )
        print( '' )
# Out:
# Источник brand не найден в итоговой статистике
# Текущий ID: 1010
# {'1010': 1}
#
# Текущий ID: 1036
# {'1010': 1, '1036': 1}
#
# Текущий ID: 1041
# {'1010': 1, '1036': 1, '1041': 1}
#
# Текущий ID: 1041
# {'1010': 1, '1036': 1, '1041': 2}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 1}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 2}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 3}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 4}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 5}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 6}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 7}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 8}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 9}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 10}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 11}
#
# ...

# %% [markdown]
# ### FORMAT()

# %%
print ('{0}- {1}- {2}'.format(10, 12.3, "string"))
# Out:
# 10- 12.3- string

# %%
mu = "chlen"
nb = "sds"
print(f"{nb} тратата {mu}")

# %%
arr = [10, 12.2, "hren"]
'{} - {} - {}'.format(*arr)
# Out:
# '10 - 12.2 - hren'

# %%
d = {"color": "red", "model": "ВМW"}
"{model} - {color}".format(**d)
# Out:
# 'ВМW - red'

# %%
"{color} - {0}".format (2010, color = "cle")
# Out:
# 'cle - 2010'

# %% [markdown]
# ### RANGE()
# range() позволяет вам генерировать ряд чисел в рамках заданного диапазона.

# %%
captains = ['Janeway', 'Picard', 'Sisko']
 
for i in range(len(captains)):
    print(captains[i])
# Out:
# Janeway
# Picard
# Sisko

# %%
for i in range(1, 8, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7

# %%
for i in range(3, 16, 3):
    quotient = i / 3
    print(f"{i} делится на 3, результат {int(quotient)}.")
# Out:
# 3 делится на 3, результат 1.
# 6 делится на 3, результат 2.
# 9 делится на 3, результат 3.
# 12 делится на 3, результат 4.
# 15 делится на 3, результат 5.

# %%
arr = [1, 2, 3]
for i in range(len(arr)):
    arr[i] *= 2
print (arr)
# Out:
# [2, 4, 6]

# %% [markdown]
# # ENUMERATE
# """Функция enwпerate (<Объект>.[, start=O J) на каждой итерации цикла for возвращает кор­
# теж из индекса и значения текущего элемента. С помощью необязательного параметра
# start можно задать начальное значение индекса."""

# %%
arr = [1, 2, 3, 4, 5, 6]
for i, e1em in enumerate(arr):
    if e1em % 2 == 0:
        arr[i] *= 2
print (arr)
# Out:
# [1, 4, 3, 8, 5, 12]

# %% [markdown]
# ### МЕТОДЫ ДЛЯ СТРОК

# %%
s = "jjsdlsjds sdlskd str , ss   "
s.upper() # прописной вариант
s.lower() # строчный
s.strip() # возвращает строку с удаленными пробелами в начале и в конце
s.startswith("str")
s.endswith("str") # возвращают True, если строка начинается или заканчивается на «str»
s.find("str") # ищет в данной строке строку «str», и возвращает индекс первого вхождения, или -1, если не найдена
s.replace("old", "new") # возвращает строку, в которой все вхождения «old» были заменены на «new»
s.split("str") # возвращает список подстрок, разделенных данным разделителем, если split() будет использован пробел)
#s.join(list)  противоположность split()соединяет элементы списка вместе, используя строку в качестве разделителя
a = ['red', 'green', 'blue']
b = 'k'.join(a)

# %%
# отключаем экронирование
S = r'C:\newt.txt'

# %% [markdown]
# ### Методы списков

# %%
list = [1, 2, 10, 3, 'b']
list2 = [1, 4]

list.append('elem') #добавляет один элемент в конец списка

list.insert(3,'elem') # вставляет элемент в заданную позицию, сдвигая элементывправо

list.extend(list2) # добавляет элементы из list2 в конец списка

list.index('b') # ищет заданный элемент с начала списка и возвращает его индекс. Выбрасывает исключение если нет

list.remove(2) # ищет первый экземпляр данного elem и удаляет его

list.clear() #очищает список

# %%
list = ['a', 'm', 'b', 'm']
list.sort() #сортирует
list.reverse() # меняет порядок
list.pop(2) #  удаляет элемент по индексу
a = list.count('m') # считает кол-во элементов в списке
print (list)
a
# Out:
# ['m', 'm', 'a']
# 2

# %%
# многомерные списки

arr = [[1,2,3],[4,5,6],[7,8,9]]
arr[0][2] # получить значение элемента
# Out:
# 3

# %%
###Срезы [START:STOP:STEP] (старт стоп шаг)
a = [1, 3, 8, 7]
a[:]
a[:3]
a[::2]
a[::-3]
a[-2::-1]
a[1:3] = [0, 0, 0] # можно также и добавлять
del a[:-3] # и удалять
# Out:
# [0, 0, 7]

# %% [markdown]
# ### функция, лямбда функция

# %%
def add (x, y, c=3):
    return x + y +c
add(1,2)
# Out:
# 6

# %%
def func(*args): #  args - это кортеж из всех переданных аргументов
    return args
func(1, 2, 3, 'abc')

def unc(**kwargs): # Функция может принимать и произвольное число именованных аргументов, тогда перед именем ставится **
    # В переменной kwargs у нас хранится словарь
    return kwargs
unc (s="sadsa", b=2, c=3)
# Out:
# {'s': 'sadsa', 'b': 2, 'c': 3}

# %%
# лямбда
func = lambda *args: args
func(1, 2, 3, 4)

f1= lambda: 10+12
f2= lambda x, y=2: x+y 
f2(1,22)
# Out:
# 23

# %% [markdown]
# ### Исключения

# %%
try: 
    x=1/0
except ZeroDivisionError:
    print ("del na 0")
    x=0
print(x)
# Out:
# del na 0
# 0

# %%
try: 
    x=1/2
except:  # все ошибки
    print ("del na 0")
    x=0
else:
    print("норм")
finally:
    print("block fin")
print(x)
# Out:
# норм
# block fin
# 0.5

# %% [markdown]
# ### with....as

# %%
with open("tast.txt", "a") as f:
    f.write("Строка\т")

# %% [markdown]
# # *args и **kwargs

# %% [markdown]
# *args и **kwargs — специальный синтаксис, позволяющий передавать в функцию переменное количество аргументов. При этом, совсем не обязательно использовать имена аргументов args и kwargs;
# *args используется для неименованных аргументов, с которыми можно работать как со списком;
# **kwargs используется для именованных аргументов, с которыми можно работать как со словарём;
# если вы хотите использовать и *args, и **kwargs, то это делается так: func(fargs, *args, **kwargs), порядок следования аргументов важен;
