# %%
#получаем аудио дорожку

import moviepy.editor as mp
p = "Последняя миссис  Пэрриш  Лив Константин (аудиокнига).mp4"
clip = mp.VideoFileClip(p)
clip.audio.write_audiofile("1.mp3")
# Out:
#
#
#
#
#
#
# ...
# t:  16%|█▋        | 1452/8834 [33:43<03:16, 37.62it/s, now=None][A
#
# t:   3%|▎         | 223/8834 [31:47<03:20, 42.91it/s, now=None]
#
#
#
# chunk:   0%|          | 0/11391 [00:00<?, ?it/s, now=None]
# MoviePy - Writing audio in 1.mp3
# chunk:   0%|          | 36/11391 [00:00<00:57, 196.97it/s, now=None]
#
#
#
# chunk:   0%|          | 56/11391 [00:00<00:59, 191.58it/s, now=None]
#
#
#
# chunk:   1%|          | 77/11391 [00:00<00:57, 196.46it/s, now=None]
#
#
#
# chunk:   1%|          | 101/11391 [00:00<00:55, 201.91it/s, now=None]
#
#
#
# chunk:   1%|          | 126/11391 [00:00<00:53, 212.07it/s, now=None]
#
#
#
# chunk:   1%|▏         | 153/11391 [00:00<00:51, 220.29it/s, now=None]
#
#
#
# chunk:   2%|▏         | 182/11391 [00:00<00:47, 235.88it/s, now=None]
#
#
#
# chunk:   2%|▏         | 223/11391 [00:00<00:41, 269.53it/s, now=None]
#
#
#
# chunk:   2%|▏         | 255/11391 [00:01<00:39, 280.20it/s, now=None]
#
#
#
# ...

# %%
#получаем только видео без звука

import moviepy.editor as mp
clip = mp.VideoFileClip("Алла Пугачева - Миллион алых роз.mp4")
clip2 = clip. set_audio ( None)
clip2.write_videofile ("videoalla_without_sound.mp4" )
# Out:
#
# t:  16%|█▋        | 1452/8834 [01:55<03:16, 37.62it/s, now=None]
#                                                                 [A
# ...
# t:   2%|▏         | 213/8834 [00:17<03:16, 43.93it/s, now=None]
#
# t:   0%|          | 0/8834 [00:00<?, ?it/s, now=None]
#
# t:   0%|          | 16/8834 [00:00<00:56, 155.47it/s, now=None]
# Moviepy - Building video videoalla_without_sound.mp4.
# Moviepy - Writing video videoalla_without_sound.mp4
# t:   0%|          | 33/8834 [00:00<00:55, 159.31it/s, now=None]
#
# t:   1%|          | 47/8834 [00:00<00:57, 152.14it/s, now=None]
#
# t:   1%|          | 57/8834 [00:00<01:21, 107.85it/s, now=None]
#
# t:   1%|          | 66/8834 [00:00<02:00, 72.56it/s, now=None]
#
# t:   1%|          | 74/8834 [00:00<02:25, 60.15it/s, now=None]
#
# t:   1%|          | 81/8834 [00:01<02:55, 49.88it/s, now=None]
#
# t:   1%|          | 87/8834 [00:01<03:07, 46.77it/s, now=None]
#
# t:   1%|          | 93/8834 [00:01<03:18, 43.95it/s, now=None]
#
# ...

# %%
#из mp4 в mp3

import moviepy.editor as mp
clip = mp.AudioFileClip("Михаил КРУГ - Мадам.mp4")
clip.write_audiofile("Михаил КРУГ - Мадам.mp3")
